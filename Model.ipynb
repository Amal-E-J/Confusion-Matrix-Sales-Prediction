# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
# test_ids = test["PassengerId"]

# %%
import matplotlib.pyplot as plt

# create scatter plot for each variable against Weekly_Sales
plt.figure(figsize=(20,20))
plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.subplot(441)
plt.scatter(df['Weekly_Sales'], df['id'])
plt.title('id vs. Weekly_Sales')
plt.subplot(442)
plt.scatter(df['Weekly_Sales'], df['IsHoliday'])
plt.title('IsHoliday vs. Weekly_Sales')
plt.subplot(443)
plt.scatter(df['Weekly_Sales'], df['Total_MarkDown'])
plt.title('Total_MarkDown vs. Weekly_Sales')
plt.subplot(444)
plt.scatter(df['Weekly_Sales'], df['Month'])
plt.title('Month vs. Weekly_Sales')
plt.subplot(445)
plt.scatter(df['Weekly_Sales'], df['Fuel_Price'])
plt.title('Fuel_Price vs. Weekly_Sales')
plt.subplot(446)
plt.scatter(df['Weekly_Sales'], df['Store'])
plt.title('Store vs. Weekly_Sales')
plt.subplot(447)
plt.scatter(df['Weekly_Sales'], df['Week'])
plt.title('Week vs. Weekly_Sales')
plt.subplot(448)
plt.scatter(df['Weekly_Sales'], df['Size'])
plt.title('Size vs. Weekly_Sales')
plt.subplot(449)
plt.scatter(df['Weekly_Sales'], df['mean'])
plt.title('mean vs. Weekly_Sales')
plt.subplot(4,4,10)
plt.scatter(df['Weekly_Sales'], df['min'])
plt.title('min vs. Weekly_Sales')
plt.subplot(4,4,11)
plt.scatter(df['Weekly_Sales'], df['CPI'])
plt.title('CPI vs. Weekly_Sales')
plt.subplot(4,4,12)
plt.scatter(df['Weekly_Sales'], df['Unemployment'])
plt.title('Unemployment vs. Weekly_Sales')
plt.subplot(4,4,13)
plt.scatter(df['Weekly_Sales'], df['Dept'])
plt.title('Dept vs. Weekly_Sales')
plt.subplot(4,4,14)
plt.scatter(df['Weekly_Sales'], df['median'])
plt.title('median vs. Weekly_Sales')
plt.subplot(4,4,15)
plt.scatter(df['Weekly_Sales'], df['max'])
plt.title('max vs. Weekly_Sales')
plt.subplot(4,4,16)
plt.scatter(df['Weekly_Sales'], df['Year'])
plt.title('Year vs. Weekly_Sales')

# add plot labels and title
plt.suptitle('Scatter Plot of Variables against Weekly_Sales')
plt.xlabel('Weekly_Sales')
plt.show()

# %%
df.corr()
# Out:
#                       id  IsHoliday  Weekly_Sales  Total_MarkDown     Month  \
# id              1.000000  -0.002292      0.001523       -0.004011  0.002027
# IsHoliday      -0.002292   1.000000     -0.004381        0.043367  0.088925
# Weekly_Sales    0.001523  -0.004381      1.000000        0.046840  0.021842
# Total_MarkDown -0.004011   0.043367      0.046840        1.000000 -0.030718
# Month           0.002027   0.088925      0.021842       -0.030718  1.000000
# Fuel_Price     -0.002625  -0.086048      0.002831        0.362782 -0.047335
# Store          -0.002313   0.006632     -0.050711       -0.058233 -0.002036
# Week            0.002090   0.089920      0.021255       -0.027416  0.995866
# Size           -0.005204  -0.017655      0.225383        0.188475 -0.004469
# mean            0.001126  -0.008441      0.958513        0.041865 -0.003838
# Temperature     0.001605  -0.134627      0.006584       -0.030169  0.240265
# ...

# %%
data
# Out:
#             id  IsHoliday  Weekly_Sales  Total_MarkDown  Month  Fuel_Price  \
# 0            1          0      13381.89        12842.28      6       3.746
# 1            2          0       3557.00            0.00      5       3.145
# 2            3          0        114.40            0.00      4       3.524
# 3            4          0         52.65            0.00      9       2.582
# 4            5          0       3043.38            0.00      3       2.654
# ...        ...        ...           ...             ...    ...         ...
# 261967  261968          0       7429.04            0.00      8       2.805
# 261968  261969          0      10443.96            0.00      4       2.725
# 261969  261970          0      34265.39         2734.47      6       4.144
# 261970  261971          0         98.00            0.00     11       2.938
# 261971  261972          0        808.00            0.00      9       2.715
#
# ...

# %%
test
# Out:
#             id  IsHoliday  Total_MarkDown  Month  Fuel_Price  Store  Week  \
# 0       261973          1        42832.84     11       3.536     40    47
# 1       261974          0        22473.00      9       4.125     10    38
# 2       261975          0            0.00      7       2.669     11    26
# 3       261976          0            0.00      3       3.488      3    11
# 4       261977          0        18065.84      9       3.821     13    39
# ...        ...        ...             ...    ...         ...    ...   ...
# 112270  374243          1        21496.76     12       3.402     29    52
# 112271  374244          0         8937.26     10       3.760     32    41
# 112272  374245          0            0.00      1       2.973     32     3
# 112273  374246          0            0.00      3       3.288      6     9
# 112274  374247          0            0.00     12       2.887     34    51
#
#           Size          mean  Temperature       min         CPI  Unemployment  \
# ...

# %%
data = data.drop(["id", "Fuel_Price", "Store", "mean", "min", "max", "Month", "median", "Year", "Week", "Date", "Type", "std"], axis=1)
test = test.drop(["id", "Fuel_Price", "Store", "mean", "min", "max", "Month", "median", "Year", "Week", "Date", "Type", "std"], axis=1)

# %%
data
# Out:
#         IsHoliday  Weekly_Sales  Total_MarkDown    Size  Temperature  \
# 0               0      13381.89        12842.28  152513        49.43
# 1               0       3557.00            0.00  126512        73.88
# 2               0        114.40            0.00   37392        68.76
# 3               0         52.65            0.00   42988        83.03
# 4               0       3043.38            0.00  158114        42.65
# ...           ...           ...             ...     ...          ...
# 261967          0       7429.04            0.00  103681        77.36
# 261968          0      10443.96            0.00  196321        41.31
# 261969          0      34265.39         2734.47   39690        92.44
# 261970          0         98.00            0.00  120653        42.05
# 261971          0        808.00            0.00  203742        75.50
#
#                CPI  Unemployment  Dept
# 0       138.117419         7.489    23
# 1       126.208548         9.524    27
# ...
